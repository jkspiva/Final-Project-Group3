# %%
import pandas as pd

# Adjust the delimiter based on your file's structure
df = pd.read_csv('bgg_dataset.csv', delimiter=';')

# Display the first few rows
print(df.head())
# Out:
#          ID                               Name  Year Published  Min Players  \
# 0  174430.0                         Gloomhaven          2017.0            1
# 1  161936.0          Pandemic Legacy: Season 1          2015.0            2
# 2  224517.0                  Brass: Birmingham          2018.0            2
# 3  167791.0                  Terraforming Mars          2016.0            1
# 4  233078.0  Twilight Imperium: Fourth Edition          2017.0            3
#
#    Max Players  Play Time  Min Age  Users Rated Rating Average  BGG Rank  \
# 0            4        120       14        42055           8,79         1
# 1            4         60       13        41643           8,61         2
# 2            4        120       14        19217           8,66         3
# 3            5        120       12        64864           8,43         4
# 4            6        480       14        13468           8,70         5
#
#   Complexity Average  Owned Users  \
# 0               3,86      68323.0
# 1               2,84      65294.0
# 2               3,91      28785.0
# 3               3,24      87099.0
# 4               4,22      16831.0
#
#                                            Mechanics  \
# 0  Action Queue, Action Retrieval, Campaign / Bat...
# 1  Action Points, Cooperative Game, Hand Manageme...
# 2  Hand Management, Income, Loans, Market, Networ...
# 3  Card Drafting, Drafting, End Game Bonuses, Han...
# 4  Action Drafting, Area Majority / Influence, Ar...
#
#                           Domains
# 0  Strategy Games, Thematic Games
# 1  Strategy Games, Thematic Games
# 2                  Strategy Games
# 3                  Strategy Games
# 4  Strategy Games, Thematic Games

# %%
# Fill NaN values in the 'ID' column with 0
df['ID'] = df['ID'].fillna(0).astype(int)

# Display the first few rows of the DataFrame to check the result
print(df.head())
# Out:
#        ID                               Name  Year Published  Min Players  \
# 0  174430                         Gloomhaven          2017.0            1
# 1  161936          Pandemic Legacy: Season 1          2015.0            2
# 2  224517                  Brass: Birmingham          2018.0            2
# 3  167791                  Terraforming Mars          2016.0            1
# 4  233078  Twilight Imperium: Fourth Edition          2017.0            3
#
#    Max Players  Play Time  Min Age  Users Rated Rating Average  BGG Rank  \
# 0            4        120       14        42055           8,79         1
# 1            4         60       13        41643           8,61         2
# 2            4        120       14        19217           8,66         3
# 3            5        120       12        64864           8,43         4
# 4            6        480       14        13468           8,70         5
#
#   Complexity Average  Owned Users  \
# 0               3,86      68323.0
# 1               2,84      65294.0
# 2               3,91      28785.0
# 3               3,24      87099.0
# 4               4,22      16831.0
#
#                                            Mechanics  \
# 0  Action Queue, Action Retrieval, Campaign / Bat...
# 1  Action Points, Cooperative Game, Hand Manageme...
# 2  Hand Management, Income, Loans, Market, Networ...
# 3  Card Drafting, Drafting, End Game Bonuses, Han...
# 4  Action Drafting, Area Majority / Influence, Ar...
#
#                           Domains
# 0  Strategy Games, Thematic Games
# 1  Strategy Games, Thematic Games
# 2                  Strategy Games
# 3                  Strategy Games
# 4  Strategy Games, Thematic Games

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20343 entries, 0 to 20342
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  20343 non-null  int32
#  1   Name                20343 non-null  object
#  2   Year Published      20342 non-null  float64
#  3   Min Players         20343 non-null  int64
#  4   Max Players         20343 non-null  int64
#  5   Play Time           20343 non-null  int64
#  6   Min Age             20343 non-null  int64
#  7   Users Rated         20343 non-null  int64
#  8   Rating Average      20343 non-null  object
#  9   BGG Rank            20343 non-null  int64
#  10  Complexity Average  20343 non-null  object
#  11  Owned Users         20320 non-null  float64
#  12  Mechanics           18745 non-null  object
#  13  Domains             10184 non-null  object
# dtypes: float64(2), int32(1), int64(6), object(5)
# memory usage: 2.1+ MB

# %%
df['Complexity Average'] = df['Complexity Average'].str.replace(',', '.').astype(float)
df.head()
# Out:
#        ID                               Name  Year Published  Min Players  \
# 0  174430                         Gloomhaven          2017.0            1
# 1  161936          Pandemic Legacy: Season 1          2015.0            2
# 2  224517                  Brass: Birmingham          2018.0            2
# 3  167791                  Terraforming Mars          2016.0            1
# 4  233078  Twilight Imperium: Fourth Edition          2017.0            3
#
#    Max Players  Play Time  Min Age  Users Rated Rating Average  BGG Rank  \
# 0            4        120       14        42055           8,79         1
# 1            4         60       13        41643           8,61         2
# 2            4        120       14        19217           8,66         3
# 3            5        120       12        64864           8,43         4
# 4            6        480       14        13468           8,70         5
#
#    Complexity Average  Owned Users  \
# 0                3.86      68323.0
# 1                2.84      65294.0
# 2                3.91      28785.0
# 3                3.24      87099.0
# 4                4.22      16831.0
#
#                                            Mechanics  \
# 0  Action Queue, Action Retrieval, Campaign / Bat...
# 1  Action Points, Cooperative Game, Hand Manageme...
# 2  Hand Management, Income, Loans, Market, Networ...
# 3  Card Drafting, Drafting, End Game Bonuses, Han...
# 4  Action Drafting, Area Majority / Influence, Ar...
#
#                           Domains
# 0  Strategy Games, Thematic Games
# 1  Strategy Games, Thematic Games
# 2                  Strategy Games
# 3                  Strategy Games
# 4  Strategy Games, Thematic Games

# %%
df['Rating Average'] = df['Rating Average'].str.replace(',', '.').astype(float)
df.head()
# Out:
#        ID                               Name  Year Published  Min Players  \
# 0  174430                         Gloomhaven          2017.0            1
# 1  161936          Pandemic Legacy: Season 1          2015.0            2
# 2  224517                  Brass: Birmingham          2018.0            2
# 3  167791                  Terraforming Mars          2016.0            1
# 4  233078  Twilight Imperium: Fourth Edition          2017.0            3
#
#    Max Players  Play Time  Min Age  Users Rated  Rating Average  BGG Rank  \
# 0            4        120       14        42055            8.79         1
# 1            4         60       13        41643            8.61         2
# 2            4        120       14        19217            8.66         3
# 3            5        120       12        64864            8.43         4
# 4            6        480       14        13468            8.70         5
#
#    Complexity Average  Owned Users  \
# 0                3.86      68323.0
# 1                2.84      65294.0
# 2                3.91      28785.0
# 3                3.24      87099.0
# 4                4.22      16831.0
#
#                                            Mechanics  \
# 0  Action Queue, Action Retrieval, Campaign / Bat...
# 1  Action Points, Cooperative Game, Hand Manageme...
# 2  Hand Management, Income, Loans, Market, Networ...
# 3  Card Drafting, Drafting, End Game Bonuses, Han...
# 4  Action Drafting, Area Majority / Influence, Ar...
#
#                           Domains
# 0  Strategy Games, Thematic Games
# 1  Strategy Games, Thematic Games
# 2                  Strategy Games
# 3                  Strategy Games
# 4  Strategy Games, Thematic Games

# %%
# Assuming 'df' has a column 'Domains' that you want to split
df_split = df['Domains'].str.split(',', expand=True)

# Add the split columns back to the original DataFrame
df[['Domain1', 'Domain2', 'Domain3']] = df_split

# Display the updated DataFrame
print(df.head())
# Out:
#        ID                               Name  Year Published  Min Players  \
# 0  174430                         Gloomhaven          2017.0            1
# 1  161936          Pandemic Legacy: Season 1          2015.0            2
# 2  224517                  Brass: Birmingham          2018.0            2
# 3  167791                  Terraforming Mars          2016.0            1
# 4  233078  Twilight Imperium: Fourth Edition          2017.0            3
#
#    Max Players  Play Time  Min Age  Users Rated  Rating Average  BGG Rank  \
# 0            4        120       14        42055            8.79         1
# 1            4         60       13        41643            8.61         2
# 2            4        120       14        19217            8.66         3
# 3            5        120       12        64864            8.43         4
# 4            6        480       14        13468            8.70         5
#
#    Complexity Average  Owned Users  \
# 0                3.86      68323.0
# 1                2.84      65294.0
# 2                3.91      28785.0
# 3                3.24      87099.0
# 4                4.22      16831.0
#
#                                            Mechanics  \
# 0  Action Queue, Action Retrieval, Campaign / Bat...
# 1  Action Points, Cooperative Game, Hand Manageme...
# 2  Hand Management, Income, Loans, Market, Networ...
# 3  Card Drafting, Drafting, End Game Bonuses, Han...
# 4  Action Drafting, Area Majority / Influence, Ar...
#
#                           Domains         Domain1          Domain2 Domain3
# 0  Strategy Games, Thematic Games  Strategy Games   Thematic Games    None
# 1  Strategy Games, Thematic Games  Strategy Games   Thematic Games    None
# 2                  Strategy Games  Strategy Games             None    None
# 3                  Strategy Games  Strategy Games             None    None
# 4  Strategy Games, Thematic Games  Strategy Games   Thematic Games    None

# %%
df = df.drop(columns=['Domains', 'Mechanics'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20343 entries, 0 to 20342
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  20343 non-null  int32
#  1   Name                20343 non-null  object
#  2   Year Published      20342 non-null  float64
#  3   Min Players         20343 non-null  int64
#  4   Max Players         20343 non-null  int64
#  5   Play Time           20343 non-null  int64
#  6   Min Age             20343 non-null  int64
#  7   Users Rated         20343 non-null  int64
#  8   Rating Average      20343 non-null  float64
#  9   BGG Rank            20343 non-null  int64
#  10  Complexity Average  20343 non-null  float64
#  11  Owned Users         20320 non-null  float64
#  12  Domain1             10184 non-null  object
#  13  Domain2             1492 non-null   object
#  14  Domain3             13 non-null     object
# dtypes: float64(4), int32(1), int64(6), object(4)
# memory usage: 2.3+ MB

# %%
df['Domain1'].unique()
# Out:
# array(['Strategy Games', 'Thematic Games', 'Family Games',
#        'Customizable Games', 'Abstract Games', 'Party Games', 'Wargames',
#        "Children's Games", nan], dtype=object)

# %%
#import pandas as pd

# Assuming 'df' is your DataFrame and has a column 'Mechanics' that you want to split
#df_split = df['Mechanics'].str.split(',', expand=True)

# Display the first few rows to confirm the split
#print(df_split.head())

# %%
# Add the first 7 split columns back to the original DataFrame with appropriate column names
#df[['Mechanic1', 'Mechanic2', 'Mechanic3', 'Mechanic4', 'Mechanic5', 'Mechanic6', 'Mechanic7']] = df_split.iloc[:, :7]

# Display the updated DataFrame to confirm the addition
#print(df.head())

# %%
# Drop the unnecessary columns (8th to 19th columns from the split)
# Note: The indexes in df_split start from 0, so columns 7 to 18 are the ones to drop
#df_split = df_split.drop(df_split.columns[7:], axis=1)

# Display the split DataFrame to confirm the columns have been dropped
#print(df_split.head())

# %%
# If you want to drop the original 'Mechanics' column from the DataFrame
#df = df.drop(columns=['Mechanics'])

# Display the final DataFrame to confirm the changes
#print(df.head())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20343 entries, 0 to 20342
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  20343 non-null  int32
#  1   Name                20343 non-null  object
#  2   Year Published      20342 non-null  float64
#  3   Min Players         20343 non-null  int64
#  4   Max Players         20343 non-null  int64
#  5   Play Time           20343 non-null  int64
#  6   Min Age             20343 non-null  int64
#  7   Users Rated         20343 non-null  int64
#  8   Rating Average      20343 non-null  float64
#  9   BGG Rank            20343 non-null  int64
#  10  Complexity Average  20343 non-null  float64
#  11  Owned Users         20320 non-null  float64
#  12  Domain1             10184 non-null  object
#  13  Domain2             1492 non-null   object
#  14  Domain3             13 non-null     object
# dtypes: float64(4), int32(1), int64(6), object(4)
# memory usage: 2.3+ MB

# %%
# Calculate the range (min and max)
min_value = df['Rating Average'].min()
max_value = df['Rating Average'].max()
value_range = max_value - min_value

# Calculate the median
median_value = df['Rating Average'].median()

# Display the results
print(f"Minimum Value: {min_value}")
print(f"Maximum Value: {max_value}")
print(f"Range: {value_range}")
print(f"Median Value: {median_value}")
# Out:
# Minimum Value: 1.05
# Maximum Value: 9.58
# Range: 8.53
# Median Value: 6.43

# %%
df['above_average'] = df['Rating Average'] > 6.43
df.head()
# Out:
#        ID                               Name  Year Published  Min Players  \
# 0  174430                         Gloomhaven          2017.0            1
# 1  161936          Pandemic Legacy: Season 1          2015.0            2
# 2  224517                  Brass: Birmingham          2018.0            2
# 3  167791                  Terraforming Mars          2016.0            1
# 4  233078  Twilight Imperium: Fourth Edition          2017.0            3
#
#    Max Players  Play Time  Min Age  Users Rated  Rating Average  BGG Rank  \
# 0            4        120       14        42055            8.79         1
# 1            4         60       13        41643            8.61         2
# 2            4        120       14        19217            8.66         3
# 3            5        120       12        64864            8.43         4
# 4            6        480       14        13468            8.70         5
#
#    Complexity Average  Owned Users         Domain1          Domain2 Domain3  \
# 0                3.86      68323.0  Strategy Games   Thematic Games    None
# 1                2.84      65294.0  Strategy Games   Thematic Games    None
# 2                3.91      28785.0  Strategy Games             None    None
# 3                3.24      87099.0  Strategy Games             None    None
# 4                4.22      16831.0  Strategy Games   Thematic Games    None
#
#    above_average
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True

# %%
df.head()
# Out:
#        ID                               Name  Year Published  Min Players  \
# 0  174430                         Gloomhaven          2017.0            1
# 1  161936          Pandemic Legacy: Season 1          2015.0            2
# 2  224517                  Brass: Birmingham          2018.0            2
# 3  167791                  Terraforming Mars          2016.0            1
# 4  233078  Twilight Imperium: Fourth Edition          2017.0            3
#
#    Max Players  Play Time  Min Age  Users Rated  Rating Average  BGG Rank  \
# 0            4        120       14        42055            8.79         1
# 1            4         60       13        41643            8.61         2
# 2            4        120       14        19217            8.66         3
# 3            5        120       12        64864            8.43         4
# 4            6        480       14        13468            8.70         5
#
#    Complexity Average  Owned Users         Domain1          Domain2 Domain3  \
# 0                3.86      68323.0  Strategy Games   Thematic Games    None
# 1                2.84      65294.0  Strategy Games   Thematic Games    None
# 2                3.91      28785.0  Strategy Games             None    None
# 3                3.24      87099.0  Strategy Games             None    None
# 4                4.22      16831.0  Strategy Games   Thematic Games    None
#
#    above_average
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True

# %%
"""
# Reset rows 401 to 600 to their original state, if you know what they were
df.loc[8000:, ['Bayesian Average', 'Most Notable Genre', 'Most Notable Mechanic', 'Price']] = None
"""
# Out:
# "\n# Reset rows 401 to 600 to their original state, if you know what they were\ndf.loc[8000:, ['Bayesian Average', 'Most Notable Genre', 'Most Notable Mechanic', 'Price']] = None\n"

# %%
"""
# Select and display the specific columns in rows 421 to 440
print(df.loc[16620:16629, ['Bayesian Average', 'Most Notable Genre', 'Most Notable Mechanic', 'Price']])
"""
# Out:
# "\n# Select and display the specific columns in rows 421 to 440\nprint(df.loc[16620:16629, ['Bayesian Average', 'Most Notable Genre', 'Most Notable Mechanic', 'Price']])\n"

# %%
"""
import requests
import xml.etree.ElementTree as ET
import pandas as pd

# Function to fetch details from BoardGameGeek API with added error handling
def fetch_game_details(game_id):
    game_id_str = str(int(game_id))
    game_url = f"https://boardgamegeek.com/xmlapi/boardgame/{game_id_str}?stats=1&pricehistory=1"
    game_response = requests.get(game_url)
    
    # Debug: Print the game ID and response status code
    print(f"Fetching details for Game ID: {game_id_str} (Status Code: {game_response.status_code})")
    
    if game_response.status_code == 200:
        try:
            game_root = ET.fromstring(game_response.content)
        except ET.ParseError as e:
            # Handle the XML parsing error
            print(f"XML parsing error for Game ID {game_id_str}: {e}")
            print("Response content:", game_response.content.decode('utf-8'))
            return "Parsing Error", "Parsing Error", "Parsing Error", "Parsing Error"
        
        bayesaverage_element = game_root.find('.//statistics/ratings/bayesaverage')
        bayesaverage = bayesaverage_element.text if bayesaverage_element is not None else "Not available"
        
        genre_element = game_root.find('.//boardgamecategory')
        genre = genre_element.text if genre_element is not None else "Not available"
        
        mechanic_element = game_root.find('.//boardgamemechanic')
        mechanic = mechanic_element.text if mechanic_element is not None else "Not available"
        
        price_element = game_root.find('.//marketplacehistory/listing/price')
        price = price_element.text if price_element is not None else "Not available"
        
        # Debug: Print the fetched data
        print(f"Bayes Average: {bayesaverage}, Genre: {genre}, Mechanic: {mechanic}, Price: {price}")
        
        return bayesaverage, genre, mechanic, price
    
    print("Failed to fetch data or game not found.")
    return "Not available", "Not available", "Not available", "Not available"

# Initialize empty lists to hold the new data
bayesaverages = []
genres = []
mechanics = []
prices = []

# Run the code on rows 1001 to 1400 of the DataFrame
for index, row in df.iloc[8000:].iterrows():  # df.iloc[1000:1400] selects rows 1001 to 1400
    game_id = row['ID']  # Ensure 'ID' is the correct column name
    
    # Check if 'Bayesian Average' is already populated for the row
    if pd.isna(row.get('Bayesian Average')) and game_id != 0:  # Skip if already populated or ID is 0
        bayesaverage, genre, mechanic, price = fetch_game_details(game_id)
    else:
        bayesaverage, genre, mechanic, price = row.get('Bayesian Average'), row.get('Most Notable Genre'), row.get('Most Notable Mechanic'), row.get('Price')
    
    # Append the results to the lists
    bayesaverages.append(bayesaverage)
    genres.append(genre)
    mechanics.append(mechanic)
    prices.append(price)

# Update the DataFrame with new data, only affecting rows 1001 to 1400 (indices 1000 to 1399)
df.loc[8000:, 'Bayesian Average'] = bayesaverages
df.loc[8000:, 'Most Notable Genre'] = genres
df.loc[8000:, 'Most Notable Mechanic'] = mechanics
df.loc[8000:, 'Price'] = prices

# Display the updated DataFrame for rows 1391 to 1400
print(df.iloc[20010:20020])
"""
# Out:
# '\nimport requests\nimport xml.etree.ElementTree as ET\nimport pandas as pd\n\n# Function to fetch details from BoardGameGeek API with added error handling\ndef fetch_game_details(game_id):\n    game_id_str = str(int(game_id))\n    game_url = f"https://boardgamegeek.com/xmlapi/boardgame/{game_id_str}?stats=1&pricehistory=1"\n    game_response = requests.get(game_url)\n    \n    # Debug: Print the game ID and response status code\n    print(f"Fetching details for Game ID: {game_id_str} (Status Code: {game_response.status_code})")\n    \n    if game_response.status_code == 200:\n        try:\n            game_root = ET.fromstring(game_response.content)\n        except ET.ParseError as e:\n            # Handle the XML parsing error\n            print(f"XML parsing error for Game ID {game_id_str}: {e}")\n            print("Response content:", game_response.content.decode(\'utf-8\'))\n            return "Parsing Error", "Parsing Error", "Parsing Error", "Parsing Error"\n        \n        bayesaverage_element = game_root.find(\'.//statistics/ratings/bayesaverage\')\n        bayesaverage = bayesaverage_element.text if bayesaverage_element is not None else "Not available"\n        \n        genre_element = game_root.find(\'.//boardgamecategory\')\n        genre = genre_element.text if genre_element is not None else "Not available"\n        \n        mechanic_element = game_root.find(\'.//boardgamemechanic\')\n        mechanic = mechanic_element.text if mechanic_element is not None else "Not available"\n        \n        price_element = game_root.find(\'.//marketplacehistory/listing/price\')\n        price = price_element.text if price_element is not None else "Not available"\n        \n        # Debug: Print the fetched data\n        print(f"Bayes Average: {bayesaverage}, Genre: {genre}, Mechanic: {mechanic}, Price: {price}")\n        \n        return bayesaverage, genre, mechanic, price\n    \n    print("Failed to fetch data or game not found.")\n    return "Not available", "Not available", "Not available", "Not available"\n\n# Initialize empty lists to hold the new data\nbayesaverages = []\ngenres = []\nmechanics = []\nprices = []\n\n# Run the code on rows 1001 to 1400 of the DataFrame\nfor index, row in df.iloc[8000:].iterrows():  # df.iloc[1000:1400] selects rows 1001 to 1400\n    game_id = row[\'ID\']  # Ensure \'ID\' is the correct column name\n    \n    # Check if \'Bayesian Average\' is already populated for the row\n    if pd.isna(row.get(\'Bayesian Average\')) and game_id != 0:  # Skip if already populated or ID is 0\n        bayesaverage, genre, mechanic, price = fetch_game_details(game_id)\n    else:\n        bayesaverage, genre, mechanic, price = row.get(\'Bayesian Average\'), row.get(\'Most Notable Genre\'), row.get(\'Most Notable Mechanic\'), row.get(\'Price\')\n    \n    # Append the results to the lists\n    bayesaverages.append(bayesaverage)\n    genres.append(genre)\n    mechanics.append(mechanic)\n    prices.append(price)\n\n# Update the DataFrame with new data, only affecting rows 1001 to 1400 (indices 1000 to 1399)\ndf.loc[8000:, \'Bayesian Average\'] = bayesaverages\ndf.loc[8000:, \'Most Notable Genre\'] = genres\ndf.loc[8000:, \'Most Notable Mechanic\'] = mechanics\ndf.loc[8000:, \'Price\'] = prices\n\n# Display the updated DataFrame for rows 1391 to 1400\nprint(df.iloc[20010:20020])\n'

# %%
"""
df.to_csv('board_game_price.csv', index=False)
"""
# Out:
# "\ndf.to_csv('board_game_price.csv', index=False)\n"

# %%
df = df.drop(columns=['ID', 'Year Published', 'BGG Rank', 'Domain3', 'Domain2'])
df.head()
# Out:
#                                 Name  Min Players  Max Players  Play Time  \
# 0                         Gloomhaven            1            4        120
# 1          Pandemic Legacy: Season 1            2            4         60
# 2                  Brass: Birmingham            2            4        120
# 3                  Terraforming Mars            1            5        120
# 4  Twilight Imperium: Fourth Edition            3            6        480
#
#    Min Age  Users Rated  Rating Average  Complexity Average  Owned Users  \
# 0       14        42055            8.79                3.86      68323.0
# 1       13        41643            8.61                2.84      65294.0
# 2       14        19217            8.66                3.91      28785.0
# 3       12        64864            8.43                3.24      87099.0
# 4       14        13468            8.70                4.22      16831.0
#
#           Domain1  above_average
# 0  Strategy Games           True
# 1  Strategy Games           True
# 2  Strategy Games           True
# 3  Strategy Games           True
# 4  Strategy Games           True

# %%
# Calculate the percentage of users rated and round to 2 decimal places
df['pct_rated'] = round(df['Users Rated'] / df['Owned Users'], 2)

df['pct_rated'].replace([float('inf'), float('-inf')], 0, inplace=True)

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#                                 Name  Min Players  Max Players  Play Time  \
# 0                         Gloomhaven            1            4        120
# 1          Pandemic Legacy: Season 1            2            4         60
# 2                  Brass: Birmingham            2            4        120
# 3                  Terraforming Mars            1            5        120
# 4  Twilight Imperium: Fourth Edition            3            6        480
#
#    Min Age  Users Rated  Rating Average  Complexity Average  Owned Users  \
# 0       14        42055            8.79                3.86      68323.0
# 1       13        41643            8.61                2.84      65294.0
# 2       14        19217            8.66                3.91      28785.0
# 3       12        64864            8.43                3.24      87099.0
# 4       14        13468            8.70                4.22      16831.0
#
#           Domain1  above_average  pct_rated
# 0  Strategy Games           True       0.62
# 1  Strategy Games           True       0.64
# 2  Strategy Games           True       0.67
# 3  Strategy Games           True       0.74
# 4  Strategy Games           True       0.80

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20343 entries, 0 to 20342
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                20343 non-null  object
#  1   Min Players         20343 non-null  int64
#  2   Max Players         20343 non-null  int64
#  3   Play Time           20343 non-null  int64
#  4   Min Age             20343 non-null  int64
#  5   Users Rated         20343 non-null  int64
#  6   Rating Average      20343 non-null  float64
#  7   Complexity Average  20343 non-null  float64
#  8   Owned Users         20320 non-null  float64
#  9   Domain1             10184 non-null  object
#  10  above_average       20343 non-null  bool
#  11  pct_rated           20320 non-null  float64
# dtypes: bool(1), float64(4), int64(5), object(2)
# memory usage: 1.7+ MB

# %%
df.fillna(0, inplace=True)

# %%
df = pd.get_dummies(df, columns=['Domain1'])
df.tail(15)
# Out:
#                        Name  Min Players  Max Players  Play Time  Min Age  \
# 20328  Hungry Hungry Hippos            2            4         10        4
# 20329                Sorry!            2            4         30        6
# 20330              Old Maid            2            6          5        4
# 20331            Mouse Trap            2            4         30        6
# 20332               Go Fish            2            6         20        4
# 20333             Operation            1            6         10        6
# 20334                   LCR            3           12         20        5
# 20335              Monopoly            2            8        180        8
# 20336      The Game of Life            2            6         60        8
# 20337               Trouble            2            4         45        4
# 20338                   War            2            2         30        4
# 20339                 Bingo            2           99         60        5
# 20340            Candy Land            2            4         30        3
# 20341    Chutes and Ladders            2            6         30        3
# 20342           Tic-Tac-Toe            2            2          1        4
#
#        Users Rated  Rating Average  Complexity Average  Owned Users  \
# 20328         2361            4.12                1.05       2568.0
# 20329         5856            4.52                1.16       9740.0
# 20330         1405            3.62                1.05       2021.0
# 20331         2693            4.11                1.11       3408.0
# 20332         1445            3.61                1.05       1223.0
# 20333         3617            4.10                1.11       6096.0
# 20334         1835            3.42                1.05       3441.0
# 20335        28999            4.39                1.65      40255.0
# 20336        10658            4.30                1.18      16692.0
# 20337         3255            3.79                1.05       4962.0
# 20338         1340            2.28                1.00        427.0
# 20339         2154            2.85                1.05       1533.0
# 20340         4006            3.18                1.08       5788.0
# 20341         3783            2.86                1.02       4400.0
# 20342         3275            2.68                1.16       1374.0
#
#        above_average  pct_rated  Domain1_0  Domain1_Abstract Games  \
# 20328          False       0.92      False                   False
# 20329          False       0.60      False                   False
# 20330          False       0.70      False                   False
# 20331          False       0.79      False                   False
# 20332          False       1.18      False                   False
# 20333          False       0.59      False                   False
# 20334          False       0.53      False                   False
# 20335          False       0.72      False                   False
# 20336          False       0.64      False                   False
# 20337          False       0.66      False                   False
# 20338          False       3.14      False                   False
# 20339          False       1.41      False                   False
# 20340          False       0.69      False                   False
# 20341          False       0.86      False                   False
# 20342          False       2.38      False                    True
#
#        Domain1_Children's Games  Domain1_Customizable Games  \
# 20328                      True                       False
# 20329                      True                       False
# 20330                      True                       False
# 20331                      True                       False
# 20332                      True                       False
# 20333                      True                       False
# 20334                      True                       False
# 20335                     False                       False
# 20336                     False                       False
# 20337                      True                       False
# 20338                      True                       False
# 20339                     False                       False
# 20340                      True                       False
# 20341                      True                       False
# 20342                     False                       False
#
#        Domain1_Family Games  Domain1_Party Games  Domain1_Strategy Games  \
# 20328                 False                False                   False
# 20329                 False                False                   False
# 20330                 False                False                   False
# 20331                 False                False                   False
# 20332                 False                False                   False
# 20333                 False                False                   False
# 20334                 False                False                   False
# 20335                  True                False                   False
# 20336                  True                False                   False
# 20337                 False                False                   False
# 20338                 False                False                   False
# 20339                 False                 True                   False
# 20340                 False                False                   False
# 20341                 False                False                   False
# 20342                 False                False                   False
#
#        Domain1_Thematic Games  Domain1_Wargames
# 20328                   False             False
# 20329                   False             False
# 20330                   False             False
# 20331                   False             False
# 20332                   False             False
# 20333                   False             False
# 20334                   False             False
# 20335                   False             False
# 20336                   False             False
# 20337                   False             False
# 20338                   False             False
# 20339                   False             False
# 20340                   False             False
# 20341                   False             False
# 20342                   False             False

# %%
pct_rated = df['pct_rated']
print(pct_rated)
# Out:
# 0        0.62
# 1        0.64
# 2        0.67
# 3        0.74
# 4        0.80
#          ...
# 20338    3.14
# 20339    1.41
# 20340    0.69
# 20341    0.86
# 20342    2.38
# Name: pct_rated, Length: 20343, dtype: float64

# %%
null_counts = df.isnull().sum().sum()
print(null_counts)
# Out:
# 0

# %%
avg_pct_rated = df['pct_rated'].mean()
avg_pct_rated
# Out:
# 0.4988546428746989

# %%
df.to_csv('boardgame_df.csv', index=False)

# %%
df.head()
# Out:
#                                 Name  Min Players  Max Players  Play Time  \
# 0                         Gloomhaven            1            4        120
# 1          Pandemic Legacy: Season 1            2            4         60
# 2                  Brass: Birmingham            2            4        120
# 3                  Terraforming Mars            1            5        120
# 4  Twilight Imperium: Fourth Edition            3            6        480
#
#    Min Age  Users Rated  Rating Average  Complexity Average  Owned Users  \
# 0       14        42055            8.79                3.86      68323.0
# 1       13        41643            8.61                2.84      65294.0
# 2       14        19217            8.66                3.91      28785.0
# 3       12        64864            8.43                3.24      87099.0
# 4       14        13468            8.70                4.22      16831.0
#
#    above_average  pct_rated  Domain1_0  Domain1_Abstract Games  \
# 0           True       0.62      False                   False
# 1           True       0.64      False                   False
# 2           True       0.67      False                   False
# 3           True       0.74      False                   False
# 4           True       0.80      False                   False
#
#    Domain1_Children's Games  Domain1_Customizable Games  Domain1_Family Games  \
# 0                     False                       False                 False
# 1                     False                       False                 False
# 2                     False                       False                 False
# 3                     False                       False                 False
# 4                     False                       False                 False
#
#    Domain1_Party Games  Domain1_Strategy Games  Domain1_Thematic Games  \
# 0                False                    True                   False
# 1                False                    True                   False
# 2                False                    True                   False
# 3                False                    True                   False
# 4                False                    True                   False
#
#    Domain1_Wargames
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False

# %%
df = df.drop(columns=['Rating Average', 'Name'])
df.head()
# Out:
#    Min Players  Max Players  Play Time  Min Age  Users Rated  \
# 0            1            4        120       14        42055
# 1            2            4         60       13        41643
# 2            2            4        120       14        19217
# 3            1            5        120       12        64864
# 4            3            6        480       14        13468
#
#    Complexity Average  Owned Users  above_average  pct_rated  Domain1_0  \
# 0                3.86      68323.0           True       0.62      False
# 1                2.84      65294.0           True       0.64      False
# 2                3.91      28785.0           True       0.67      False
# 3                3.24      87099.0           True       0.74      False
# 4                4.22      16831.0           True       0.80      False
#
#    Domain1_Abstract Games  Domain1_Children's Games  \
# 0                   False                     False
# 1                   False                     False
# 2                   False                     False
# 3                   False                     False
# 4                   False                     False
#
#    Domain1_Customizable Games  Domain1_Family Games  Domain1_Party Games  \
# 0                       False                 False                False
# 1                       False                 False                False
# 2                       False                 False                False
# 3                       False                 False                False
# 4                       False                 False                False
#
#    Domain1_Strategy Games  Domain1_Thematic Games  Domain1_Wargames
# 0                    True                   False             False
# 1                    True                   False             False
# 2                    True                   False             False
# 3                    True                   False             False
# 4                    True                   False             False

# %%
X = df.copy()
X.drop('above_average', axis=1, inplace=True)
X.head()
# Out:
#    Min Players  Max Players  Play Time  Min Age  Users Rated  \
# 0            1            4        120       14        42055
# 1            2            4         60       13        41643
# 2            2            4        120       14        19217
# 3            1            5        120       12        64864
# 4            3            6        480       14        13468
#
#    Complexity Average  Owned Users  pct_rated  Domain1_0  \
# 0                3.86      68323.0       0.62      False
# 1                2.84      65294.0       0.64      False
# 2                3.91      28785.0       0.67      False
# 3                3.24      87099.0       0.74      False
# 4                4.22      16831.0       0.80      False
#
#    Domain1_Abstract Games  Domain1_Children's Games  \
# 0                   False                     False
# 1                   False                     False
# 2                   False                     False
# 3                   False                     False
# 4                   False                     False
#
#    Domain1_Customizable Games  Domain1_Family Games  Domain1_Party Games  \
# 0                       False                 False                False
# 1                       False                 False                False
# 2                       False                 False                False
# 3                       False                 False                False
# 4                       False                 False                False
#
#    Domain1_Strategy Games  Domain1_Thematic Games  Domain1_Wargames
# 0                    True                   False             False
# 1                    True                   False             False
# 2                    True                   False             False
# 3                    True                   False             False
# 4                    True                   False             False

# %%
y = df['above_average']

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
scaler = StandardScaler()
X_scaler = scaler.fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

rf_model = RandomForestClassifier(n_estimators=500, random_state=78)
rf_model = rf_model.fit(X_train_scaled, y_train)

# %%
predictions = rf_model.predict(X_test_scaled)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
# %matplotlib inline

# Calculating the confusion matrix
cm = confusion_matrix(y_test, predictions)
cm_df = pd.DataFrame(
    cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"]
)

# Calculating the accuracy score
acc_score = accuracy_score(y_test, predictions)

# %%
# Displaying results
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix
#           Predicted 0  Predicted 1
# Actual 0         1976          593
# Actual 1          734         1783
# Accuracy Score : 0.7390876917027134
# Classification Report
#               precision    recall  f1-score   support
#
#        False       0.73      0.77      0.75      2569
#         True       0.75      0.71      0.73      2517
#
#     accuracy                           0.74      5086
#    macro avg       0.74      0.74      0.74      5086
# weighted avg       0.74      0.74      0.74      5086

# %%
# Random Forests in sklearn will automatically calculate feature importance
importances = rf_model.feature_importances_
# We can sort the features by their importance
sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.21619248023474696, 'Complexity Average'),
#  (0.16657236170707163, 'Owned Users'),
#  (0.15730986165107502, 'Users Rated'),
#  (0.12426507301495612, 'pct_rated'),
#  (0.09798546128998696, 'Play Time'),
#  (0.07583653609069774, 'Min Age'),
#  (0.0622836768803171, 'Max Players'),
#  (0.04341084029160012, 'Min Players'),
#  (0.012012820041333507, 'Domain1_0'),
#  (0.010204001764151897, 'Domain1_Wargames'),
#  (0.007797862833688147, 'Domain1_Strategy Games'),
#  (0.005920841868914681, 'Domain1_Family Games'),
#  (0.005650714125774866, "Domain1_Children's Games"),
#  (0.004893616682307069, 'Domain1_Abstract Games'),
#  (0.0039056102672454444, 'Domain1_Thematic Games'),
#  (0.0033922769860310208, 'Domain1_Customizable Games'),
#  (0.0023659642701017473, 'Domain1_Party Games')]

# %%
# Visualize the features by importance
importances_df = pd.DataFrame(sorted(zip(rf_model.feature_importances_, X.columns), reverse=True))
importances_df.set_index(importances_df[1], inplace=True)
importances_df.drop(columns=1, inplace=True)
importances_df.rename(columns={0: 'Feature Importances'}, inplace=True)
importances_sorted = importances_df.sort_values(by='Feature Importances')
importances_sorted.plot(kind='barh', color='lightgreen', title= 'Features Importances', legend=False)
# Out:
# <Axes: title={'center': 'Features Importances'}, ylabel='1'>
